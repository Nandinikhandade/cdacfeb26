# %%
import numpy as np
import pandas as pd
from numpy import random
import os
os.getcwd()     #get current working directory
os.chdir("/content/drive/MyDrive")
os.getcwd
df=pd.read_excel('CDAC_DataBook (1).xlsx',sheet_name='ERPData')
df.head()       #by default 5 rows ahe shown
import scipy
from scipy import stats
from scipy.stats import norm, t
from collections import Counter
from scipy.stats import binom
from scipy.stats import poisson

# %%
import scipy
from scipy import stats
from scipy.stats import norm, t, binom, poisson

# %%
norm.cdf(43,45,2.8)
# Out:
# np.float64(0.2375252620269765)

# %%
z=(43-45)/2.8

# %%
z
# Out:
# -0.7142857142857143

# %%
norm.cdf(z,0,1)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.cdf(z)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.cdf(1.73)
# Out:
# np.float64(0.9581848623864051)

# %% [markdown]
# student t distribution

# %%
z=(14-15.3)/1.8

# %%
t.cdf(2,14)
# Out:
# np.float64(0.967356023555444)

# %%
norm.cdf(z)
# Out:
# np.float64(0.23507893142883468)

# %%
t.cdf(z,1499)
# Out:
# np.float64(0.2351352562574976)

# %% [markdown]
# expontential distribution

# %%
from scipy.stats import expon

# %%
expon.cdf(100,scale=43.8)
# Out:
# np.float64(0.898032895521957)

# %%
24/80
# Out:
# 0.3

# %%
expon.cdf(1,scale=0.3). # horn is heard
# Out:
# np.float64(0.9643260066527476)

# %%
1-expon.cdf(1,scale=0.3). # horn is not heard
# Out:
# np.float64(0.03567399334725241)

# %%
45*8/30
# Out:
# 12.0

# %%
expon.cdf(8,scale=12)
# Out:
# np.float64(0.486582880967408)

# %% [markdown]
# # **EDA**

# %%
df=pd.read_excel('data1.xlsx')

# %%
df.head()
# Out:
#   Category
# 0        C
# 1        D
# 2        C
# 3        A
# 4        B

# %%
df.Category.isnull().sum() # count the number of missisng values
# Out:
# np.int64(80)

# %%
np.where(df.Category.isnull())
# Out:
# (array([  9,  11,  15,  32,  35,  38,  47,  48,  58,  59,  62,  64,  80,
#          81,  82,  84,  95,  98, 122, 123, 140, 156, 161, 163, 164, 165,
#         166, 167, 170, 174, 176, 177, 188, 192, 193, 212, 217, 223, 227,
#         231, 237, 238, 246, 248, 250, 254, 257, 260, 267, 268, 269, 278,
#         281, 287, 303, 328, 329, 333, 342, 345, 349, 357, 382, 384, 387,
#         404, 406, 441, 445, 447, 451, 456, 459, 464, 471, 476, 477, 490,
#         492, 494]),)

# %%
80/df.shape[0]
# Out:
# 0.16

# %%
from collections import Counter

# %%
Counter(df.Category).most_common()
# Out:
# [('B', 113), ('A', 112), ('C', 101), ('D', 94), (nan, 80)]

# %%
df.Category.fillna('B')
# Out:
# 0      C
# 1      D
# 2      C
# 3      A
# 4      B
#       ..
# 495    C
# 496    C
# 497    D
# 498    B
# 499    A
# Name: Category, Length: 500, dtype: object

# %%
df.head(10)
# Out:
#   Category
# 0        C
# 1        D
# 2        C
# 3        A
# 4        B
# 5        A
# 6        B
# 7        C
# 8        D
# 9      NaN

# %%
df.Category=df.Category.fillna('B')

# %%
df.Category.isnull().sum()
# Out:
# np.int64(0)

# %%
props=pd.DataFrame(df.Category.value_counts())

# %%
props
# Out:
#           count
# Category
# B           193
# A           112
# C           101
# D            94

# %%
props['proportion']= props['count']/sum(props['count'])

# %%
props
# Out:
#           count  proportion
# Category
# B           193       0.386
# A           112       0.224
# C           101       0.202
# D            94       0.188

# %%
random_values=np.random.choice(['A','B','C','D'],size=80,p=props.proportion) # randomly select values from a,b,c,d  that size of 80 in the same proportion

# %%
random_values
# Out:
# array(['B', 'A', 'B', 'D', 'C', 'B', 'B', 'C', 'C', 'D', 'C', 'D', 'B',
#        'C', 'B', 'B', 'D', 'B', 'A', 'B', 'A', 'C', 'B', 'A', 'D', 'B',
#        'C', 'B', 'A', 'B', 'A', 'A', 'D', 'A', 'D', 'D', 'D', 'B', 'C',
#        'D', 'C', 'B', 'B', 'D', 'B', 'D', 'B', 'A', 'C', 'A', 'B', 'B',
#        'C', 'A', 'C', 'A', 'D', 'A', 'A', 'B', 'D', 'B', 'C', 'A', 'A',
#        'C', 'A', 'A', 'A', 'B', 'A', 'B', 'A', 'D', 'B', 'C', 'A', 'B',
#        'D', 'D'], dtype='<U1')

# %%
props
# Out:
#           count  proportion
# Category
# B           193       0.386
# A           112       0.224
# C           101       0.202
# D            94       0.188

# %%
ind=np.where(df.Category.isnull())

# %%
df.Category.isnull().sum()
# Out:
# np.int64(80)

# %%
df.loc[ind[0],'Category'] = random_values

# %%
df
# Out:
#     Category
# 0          C
# 1          D
# 2          C
# 3          A
# 4          B
# ..       ...
# 495        C
# 496        C
# 497        D
# 498        B
# 499        A
#
# [500 rows x 1 columns]

# %%
df.Category.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Quantity.fillna(df.Quantity.median()) # In df there are no column of quantity
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1331/819282740.py in <cell line: 0>()
# ----> 1 df.Quantity.fillna(df.Quantity.median())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Quantity'

# %%
df1=pd.read_excel('data2.xlsx')

# %%
df1.head()
# Out:
#   Category  Continuous_Value
# 0        C      -4008.098297
# 1        D      -3887.888132
# 2      NaN      -3712.188312
# 3        C      -3416.823821
# 4        D      -5845.073897

# %%
df1.info()        #step 1     wnen any dataset is given
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Category          850 non-null    object
#  1   Continuous_Value  880 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 15.8+ KB

# %%
df1.Continuous_Values=df1.Continuous_Value.median()

# %% [markdown]
# # **seaborn matplotlib**

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pylab
from pylab import legend
from pylab import plot,show,title,xlabel,ylabel

# %%
states=['KA','MH','AP','MP','UP']
counts=[40,35,50,20,15]

# %%
plt.bar(states,counts)      # matplotlib
# Out:
# <BarContainer object of 5 artists>

# %%
sns.barplot(x=states,y=counts)     #seaborns
# Out:
# <Axes: >

# %%
plt.title('this is my first graph')
# Out:
# Text(0.5, 1.0, 'this is my first graph')

# %%
plt.xlabel("name of the states")
# Out:
# Text(0.5, 0, 'name of the states')

# %%
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
sns.barplot(x=states,y=counts)     #seaborns
plt.title('this is my first graph')
plt.xlabel("name of the states")
plt.ylabel('Counts')

plt.show()

# %%
df=pd.read_excel('CDAC_DataBook (1).xlsx',sheet_name='ERPData')

# %%
df1=df.MaterialID.value_counts()

# %%
plt.bar(df1.index,df1)      # barplot for frequency
# Out:
# <BarContainer object of 6 artists>

# %%
grp1=df.groupby('MaterialID')
df2=grp1.Quantity.agg('sum')
plt.bar(df2.index,df2)    # bar chart for total
# Out:
# <BarContainer object of 6 artists>

# %%
df1=pd.crosstab(df.Location,df.MaterialID)             #( broadcast join in sql )

# %%
df1
# Out:
# MaterialID  AXCP-78  DDBN-89  GCVB-79  LXCV-21  SDRT-67  TMI-43T
# Location
# MWH-1             5        3        0        0        2        1
# MWH-2             1        1        4        1        1        1
# MWH-3             1        1        0        1        0        1
# MWH-4             1        2        0        0        1       11
# MWH-5             3        1        1        3        2        1

# %%
df1.plot(kind='bar')      # group bar chart     there are two categorical data
# Out:
# <Axes: xlabel='Location'>

# %%
df=pd.read_excel('CDAC_DataBook (1).xlsx',sheet_name='nominal')       #ses-- social economic status

# %%
df.head()
# Out:
#    ses  write  math  prog
# 0    1     35    41     1
# 1    2     33    41     2
# 2    3     39    44     3
# 3    1     37    42     1
# 4    2     31    40     2

# %%
df1=pd.crosstab(df.ses,df.prog)

# %%
df1
# Out:
# prog   1   2   3
# ses
# 1     29  16   2
# 2      6  51  38
# 3      1   9  48

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='ses'>

# %%
#effect of a categorical data on another categorical data. ,we make a group bar chart

# %%
df=pd.read_excel('CDAC_DataBook (1).xlsx',sheet_name='ERPData')

# %%
plt.boxplot(df.Quantity)        #boxplot always use with continous data
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cd67c328d40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7cd67c2d3c80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7cd67c32a810>],
#  'medians': [<matplotlib.lines.Line2D at 0x7cd67c2d12e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7cd67c2d3710>],
#  'means': []}

# %%
male_sal=[4,6,5,3,7,6,8]

# %%
female_sal =[11,15,13,19,15]

# %%
plt.boxplot([male_sal,female_sal])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cd67c33d4f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7cd67c33f740>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7cd67c33e570>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7cd67c33f770>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7cd67c33df40>,
# ...
#  'means': []}

# %%
 #effect of a categorical data on another categorical data .........continueous data

# %% [markdown]
# # **Day 8**

# %%
df=pd.read_excel('CDAC_DataBook (1).xlsx',sheet_name='ERPData')

# %%
grp1=df.groupby('MaterialID')

# %%
df1=grp1.Quantity.agg('sum')

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df2=pd.crosstab(df.MaterialID,df.Location)

# %%
df2
# Out:
# Location    MWH-1  MWH-2  MWH-3  MWH-4  MWH-5
# MaterialID
# AXCP-78         5      1      1      1      3
# DDBN-89         3      1      1      2      1
# GCVB-79         0      4      0      0      1
# LXCV-21         0      1      1      0      3
# SDRT-67         2      1      0      1      2
# TMI-43T         1      1      1     11      1

# %%
df2.plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df3=pd.crosstab(df.MaterialID,df.Location,values=df.Quantity,aggfunc='sum')

# %%
df3.plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df4=df.pivot_table(values='Quantity',index='MaterialID',columns='Location',aggfunc='sum')

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
#seaborn
sns.barplot(x = 'MaterialID',y = 'Quantity',hue = 'Location',data = df,ci=None,estimator=np.sum)
# Out:
# /tmp/ipykernel_10355/2573962399.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'MaterialID',y = 'Quantity',hue = 'Location',data = df,ci=None,estimator=np.sum)
# <Axes: xlabel='MaterialID', ylabel='Quantity'>

# %%
x1=[5,6,4,3,5,6,7,8,9,6,6,3,6]
x2=[3,5,4,5,6,7,6,5,4,5,6,7,8,2,3,5]
x3=[4,5,3,4,5,7,8,9,4,3,6,8]

# %%
plt.boxplot([x1,x2,x3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x782d676205c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x782d64727ec0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x782d66da4fe0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x782d64725880>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x782d64725c40>,
# ...
#  'means': []}

# %%
#seaborn
sns.boxplot(data=[x1,x2,x3])
# Out:
# <Axes: >

# %% [markdown]
# **histogram** - contineous alone
#
# x- axis variable will be contieous data only and the bars wil touch each

# %% [markdown]
# **scatter plot**
#
# contieous data used when effect of contineous data establish on contineous

# %%
df=pd.read_excel('CDAC_DataBook (1).xlsx',sheet_name='faithful')

# %%
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
plt.scatter(df.eruptions,df.waiting, color ='purple')

# %% [markdown]
# single contienous data called **histogram**

# %%
cats=[1.5,2.1,3.5,4.2,5.2]

# %%
plt.hist(df.eruptions,cats)
# Out:
# (array([ 63.,  41.,  61., 107.]),
#  array([1.5, 2.1, 3.5, 4.2, 5.2]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(df.eruptions,color='skyblue')
# Out:
# (array([45., 36., 13.,  3.,  4., 12., 29., 52., 54., 24.]),
#  array([1.6 , 1.95, 2.3 , 2.65, 3.  , 3.35, 3.7 , 4.05, 4.4 , 4.75, 5.1 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# uni variate analaysis -----simple bar char (only single variable at a time)
#
# bivariate ----simulateously anaysis of two variables
#
# multivariate--- it involes multiple variables at the same time to find corelataion between them

# %%
df1 = df.iloc[np.where(df.eruptions<=3.6)]
df2 = df.iloc[np.where(df.eruptions>3.6)]

plt.scatter(df1.eruptions, df1.waiting, c='red')
plt.scatter(df2.eruptions, df2.waiting, c='blue')
plt.show()

# %% [markdown]
# all the point group by categorical data

# %%
df=sns.load_dataset('titanic')

# %%
class_counts=df['class'].value_counts()

# %%
#matplotlib
plt.bar(class_counts.index,class_counts.values)
# Out:
# <BarContainer object of 3 artists>

# %%
#seaborn
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
sns.countplot(x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.barplot(x='class',y='fare',data=df,ci=None)
# Out:
# /tmp/ipykernel_10355/1215410460.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='class',y='fare',data=df,ci=None)
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.histplot(df.eruptions)
# Out:
# <Axes: xlabel='eruptions', ylabel='Count'>

# %%
group1 = np.random.normal(loc=10, scale=2, size=100)  # Volcano A mean is 10 and std dev=2
group2 = np.random.normal(loc=12, scale=2.5, size=100)  # e.g., Volcano B

bins = np.linspace(5, 20, 15)  # common bin edges for both groups

plt.hist(group1, bins=bins, alpha=0.6, label='Volcano A', color='blue', edgecolor='black')
plt.hist(group2, bins=bins, alpha=0.6, label='Volcano B', color='yellow', edgecolor='black')
plt.show()

# %%
df=pd.read_excel('ManHours.xlsx')

# %%
df
# Out:
#    Name Client  Hours Grade  Team
# 0     A   CDAC      3     A     2
# 1     B   CDAC      4     A     2
# 2     A   Infy      2     B     1
# 3     C   Infy      4     C     3
# 4     A   CDAC      3     A     2
# 5     B    TCS      5     A     1
# 6     A   Infy      3     C     2
# 7     A    TCS      3     B     2
# 8     C   Infy      4     A     3
# 9     C    TCS      3     A     1
# 10    A   CDAC      4     B     1
# 11    A   Infy      3     A     2
# 12    A    TCS      4     B     3
# 13    B   Infy      2     A     1
# 14    C   CDAC      3     C     3
# 15    B    TCS      4     B     2

# %%
single categroical data = barchart

# %%
df=pd.read_csv('6-Churn_ModellingDataSet.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df=df.drop(['RowNumber','CustomerId','Surname'],axis=1)

# %%
plt.boxplot(df.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x782d5c677b90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x782d5c5681d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x782d5c6778f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x782d5c568800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x782d5c568b30>],
#  'means': []}

# %%
exit_counts=df.Exited.value_counts()

# %%
exit_prop=pd.DataFrame(exit_counts)

# %%
exit_prop['proportion']=exit_prop['count']/sum(exit_prop['count'])

# %%
exit_prop
# Out:
#         count  proportion
# Exited
# 0        7963      0.7963
# 1        2037      0.2037

# %%
df0=df.iloc[np.where(df.Exited==0)]
df1=df.iloc[np.where(df.Exited==1)]
plt.boxplot([df0.EstimatedSalary,df1.EstimatedSalary])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x782d5c476fc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x782d5c477560>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x782d5c476d50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x782d5c477a10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x782d5c477c80>,
# ...
#  'means': []}

# %%
plt.boxplot([df0.Age,df1.Age])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x782d5c31c9b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x782d5c31cfe0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x782d5c31c770>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x782d5c31d550>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x782d5c31d880>,
# ...
#  'means': []}

# %%
np.median(df1.Age)
# Out:
# np.float64(45.0)

# %%
plt.boxplot([df0.CreditScore,df1.CreditScore])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x782d5c2f07a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x782d5c2f0200>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x782d5c2f0fb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x782d5bf3d880>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x782d5c2f3c20>,
# ...
#  'means': []}

# %%
df_400=df.iloc[np.where(df.CreditScore<=400)]

# %%
exit_400=df_400.Exited.value_counts()

# %%
exit_400
# Out:
# Exited
# 1    19
# Name: count, dtype: int64

# %%
152/(152+491)
# Out:
# 0.2363919129082426

# %%
geo=pd.crosstab(df.Geography,df.Exited)

# %%
geo
# Out:
# Exited        0    1
# Geography
# France     4204  810
# Germany    1695  814
# Spain      2064  413

# %%
geo.plot(kind='bar')
# Out:
# <Axes: xlabel='Geography'>

# %%
geo['prop']=geo[1]/(geo[0]+geo[1])

# %%
geo
# Out:
# Exited        0    1      prop
# Geography
# France     4204  810  0.161548
# Germany    1695  814  0.324432
# Spain      2064  413  0.166734

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
cc=pd.crosstab(df.HasCrCard,df.Exited)

# %%
cc.plot(kind='bar')
# Out:
# <Axes: xlabel='HasCrCard'>

# %%
cc['prop']=cc[1]/(cc[0]+cc[1])

# %%
cc
# Out:
# Exited        0     1      prop
# HasCrCard
# 0          2332   613  0.208149
# 1          5631  1424  0.201843

# %%
gender=pd.crosstab(df.Gender,df.Exited)

# %%
gender.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
gender['prop']=gender[1]/(gender[0]+gender[1])

# %%
gender
# Out:
# Exited     0     1      prop
# Gender
# Female  3404  1139  0.250715
# Male    4559   898  0.164559

# %%
1139/(1139+898)
# Out:
# 0.5591556210112911

# %%
pt=df.pivat_table(values='Exited',index='Geography',columns='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10355/2238868853.py in <cell line: 0>()
# ----> 1 pt=df.pivat_table(values='Exited',index='Geography',columns='')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'pivat_table'

# %%
pt

# %%
pt['prop']=pt['Female']/(pt['Female']+pt['Male'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10355/2241689337.py in <cell line: 0>()
# ----> 1 pt['prop']=pt['Female']/(pt['Female']+pt['Male'])
#
# NameError: name 'pt' is not defined

# %%
pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10355/482749120.py in <cell line: 0>()
# ----> 1 pt
#
# NameError: name 'pt' is not defined

# %%
tb1=pd.crosstab(df.IsActiveMember,df.Exited)

# %%
tb1.plot.bar()
# Out:
# <Axes: xlabel='IsActiveMember'>

# %%
tb1
# Out:
# Exited             0     1
# IsActiveMember
# 0               3547  1302
# 1               4416   735

# %%
tb1['prop']=tb1[1]/(tb1[1]+tb1[0])

# %%
tb1
# Out:
# Exited             0     1      prop
# IsActiveMember
# 0               3547  1302  0.268509
# 1               4416   735  0.142691

# %%
1302/(1302+3547)
# Out:
# 0.26850897092183956

# %%
735/(735+4416)
# Out:
# 0.14269073966220153
